# %%
import pandas as pd
import json
from pandas import json_normalize

# %%
# Baca file JSON dengan encoding 'utf-8'
with open('products_data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Periksa data yang dibaca
print(data)
# Out:
# [{'oldId': 5624872374, 'id': '5624872374', 'layout': 'product', 'layoutTracker': 'product', 'dataStringJson': '', 'url': 'https://www.tokopedia.com/budinugrohoshop/gelang-paperklip-anak-16k-3-10-g', 'name': 'GELANG PAPERKLIP ANAK 16K', 'subtitle': '', 'price': 'Rp6.059.000', 'rating': 5, 'applink': 'tokopedia://product/5624872374', 'clickUrl': '', 'imageUrl': 'https://p16-images-sign-sg.tokopedia-static.net/tos-alisg-i-aphluv4xwc-sg/img/VqbcmM/2023/3/10/6f1e8000-2c9d-4366-a38b-c2087c5b5505.jpg~tplv-aphluv4xwc-white-pad-v1:200:200.jpeg?lk3s=67a35ccb&x-expires=1766076649&x-signature=%2BZIUUELYuUtVVQpw4pIONODdvRI%3D&x-signature-webp=IZ5BWH%2FqiT%2FS9IoqWjvzfSA4tHY%3D', 'iconUrl': '', 'isTopads': False, 'priceInt': 6059000, 'clusterID': 0, 'productKey': 'gelang-paperklip-anak-16k-3-10-g', 'isWishlist': False, 'wishlistUrl': '', 'countReview': 105, 'slashedPrice': '', 'ratingAverage': '5.0', 'trackerImageUrl': 'https://p16-images-sign-sg.tokopedia-static.net/tos-alisg-i-aphluv4xwc-sg/img/
# ...

# %%
# Membaca file JSON dengan pandas menggunakan encoding 'utf-8'
df = pd.read_json('products_data.json', encoding='utf-8')

# Simpan data ke file CSV
df.to_csv('products_data.csv', index=False, encoding='utf-8')
